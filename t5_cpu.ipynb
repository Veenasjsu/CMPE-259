# %%
pip install sentencepiece
# Out:
# Requirement already satisfied: sentencepiece in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (0.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import time
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.llms import HuggingFacePipeline
from langchain.chains import RetrievalQA
from transformers import T5ForConditionalGeneration, T5Tokenizer
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
import pickle

# Initialize the embedding model
embeddings = HuggingFaceEmbeddings(model_kwargs={"device": "cpu"})

# Load your FAISS index
vectorstore = FAISS.load_local(
    "faiss_index", 
    embeddings,
    allow_dangerous_deserialization=True
)

# Create retriever from FAISS index
retriever = vectorstore.as_retriever(search_kwargs={"k": 5})  # Increase top_k for better results

# Load pre-trained SentenceTransformer model for semantic similarity
similarity_model = SentenceTransformer('all-MiniLM-L6-v2', device='cpu')  # Lightweight and fast

# Load the questions and answers file
def load_questions_and_answers(filename):
    questions_and_answers = {}
    with open(filename, 'r') as file:
        lines = file.readlines()
    i = 0
    while i < len(lines):
        # Read the question (assuming questions are one line long)
        question = lines[i].strip()
        i += 1
        # Collect answer lines (answers may span multiple lines)
        answer_lines = []
        while i < len(lines) and lines[i].strip() != "":
            answer_lines.append(lines[i].strip())
            i += 1
        # Join the answer lines into a single string
        answer = "\n".join(answer_lines)
        # Only add to dictionary if both question and answer are non-empty
        if question and answer:
            questions_and_answers[question] = answer
        while i < len(lines) and lines[i].strip() == "":
            i += 1
    return questions_and_answers

# Function to generate answers using the T5 model
def generate_answer_with_t5(question, context):
    tokenizer = T5Tokenizer.from_pretrained("t5-large")
    model = T5ForConditionalGeneration.from_pretrained("t5-large")
    
    input_text = f"question: {question} context: {context}"
    input_ids = tokenizer(input_text, return_tensors="pt").input_ids
    output = output = model.generate(
        input_ids,
        min_length=100,
        max_length=200,  # Increase the max length for more detailed responses
        num_beams=4,  # Beam search to improve response quality
        no_repeat_ngram_size=2,  # Avoid repetition of n-grams in the response
        length_penalty=1.0,  # Encourage longer answers
        early_stopping=True
    )
    return tokenizer.decode(output[0], skip_special_tokens=True)

# Evaluate the VA performance using T5
def evaluate_va(filename):
    # Load questions and answers from the text file
    correct_answers = load_questions_and_answers(filename)
    
    results = {
        'question': [],
        'context': [],
        'answer': [],
        'time': [],
        'correct': [],
        'similarity_score': []
    }

    for question, expected_answer in correct_answers.items():
        results['question'].append(question)

        # Evaluate with the retriever
        start_time = time.time()

        # Retrieve relevant documents based on the question
        retriever_result = retriever.get_relevant_documents(question, top_k=5)
        context = " ".join([doc.page_content for doc in retriever_result])  # Combine context from multiple docs

        results['context'].append(context)

        # Ensure the context isn't empty
        if not question.strip() or not context.strip():
            print(f"Warning: Empty question or context for input.")
            continue

        # Get the response from the T5 model
        response = generate_answer_with_t5(question, context)

        elapsed_time = time.time() - start_time

        # Append results
        results['answer'].append(response)
        results['time'].append(elapsed_time)

        # Calculate similarity score
        response_embedding = similarity_model.encode(response, convert_to_tensor=True)
        expected_embedding = similarity_model.encode(expected_answer, convert_to_tensor=True)

        similarity_score = cosine_similarity(
            response_embedding.unsqueeze(0).cpu().numpy(),
            expected_embedding.unsqueeze(0).cpu().numpy()
        )[0][0]

        results['similarity_score'].append(similarity_score)

        # Check if the similarity score exceeds the threshold (0.4 for acceptable match)
        is_correct = 1 if similarity_score > 0.4 else 0
        results['correct'].append(is_correct)

    return results

# File containing questions and answers
filename = './nlp/questions_and_answers.txt'

# Evaluate the VA performance using T5
evaluation_results = evaluate_va(filename)

# Calculate accuracy
t5_accuracy = sum(evaluation_results['correct']) / len(evaluation_results['question']) * 100
print(f"T5 Accuracy: {t5_accuracy:.2f}%")

# Calculate the average time taken
average_time = sum(evaluation_results['time']) / len(evaluation_results['time'])

# Print the average time
print(f"Average Time Taken: {average_time:.2f} seconds")

# Print detailed results
print("\nDetailed Results:")
for i in range(len(evaluation_results['question'])):
    print("======================================Question==========================================")
    print(f"{evaluation_results['question'][i]:<30}")
    # print("-------------------------------------Context--------------------------------------------")
    # print(f"{evaluation_results['context'][i]:<50}")
    print("-------------------------------------Answer--------------------------------------------")
    print(f"{evaluation_results['answer'][i]:<50}")
    print("-------------------------------------Evaluation----------------------------------------")
    print(f"{evaluation_results['time'][i]:<15.2f} {evaluation_results['similarity_score'][i]:<15}")
# Out:
# /tmp/ipykernel_1307/776523366.py:13: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings(model_kwargs={"device": "cpu"})
# T5 Accuracy: 86.67%
# Average Time Taken: 44.80 seconds
#
# Detailed Results:
# ======================================Question==========================================
# What is a list in Python and how are lists defined?
# -------------------------------------Answer--------------------------------------------
# square brackets []. Lists are defined using parentheses ().  Tuples: A tuple is similar to a list but immutable. It is defining pd.DataFrame(data) # Display the DataFrape print(df)# Display data in the filtered_diff (dif x = 0) . Python for Data Analysis Python is the go-to language for data analysis and machine learning
# -------------------------------------Evaluation----------------------------------------
# 44.45           0.5138731598854065
# ======================================Question==========================================
# How do you define a function in Python?
# -------------------------------------Answer--------------------------------------------
# using the def keyword. Python also supports lambda functions for simple expressions.  Functions in Python are defined using __decorator(func): print("Before the function call") func() - wrapper(): df[['Age'] > 30] # Display the DataFrame a tuple containing the name of the person you are working with. import numpy as np # Create an NumPy array
# -------------------------------------Evaluation----------------------------------------
# 43.02           0.4850350022315979
# ======================================Question==========================================
# What is a dictionary in Python and how is it defined?
# -------------------------------------Answer--------------------------------------------
# a dictionary in Python is an unordered collection of key-value pairs. Dictionaries are defined using curly braces  . df = pd.DataFrame(data) # Display the data frame '('name')' # Print the first post json_data = ['Alice'] - ('Los Angeles'-) __decorator(func): print("After the function call")
# -------------------------------------Evaluation----------------------------------------
# 42.79           0.6456774473190308
# ======================================Question==========================================
# what are Python Decorators?
# -------------------------------------Answer--------------------------------------------
# functions that modify the behavior of other functions or methods. They are commonly used for logging, access control, memoization, and performance measurement . A class decorator is used to modify or enhance the functionality of a class. Creating Custom Iterators In addition to function decorators, Python also supports __next________() methods - if self.current > self-end: raise StopIteration i in itertools.count()
# -------------------------------------Evaluation----------------------------------------
# 39.08           0.786761999130249
# ======================================Question==========================================
# Question 5: What is Mathplotlib?
# -------------------------------------Answer--------------------------------------------
# A plotting library that provides a wide variety of chart types and customization options . import matplotlib.pymap as plt import numpy as np.linspace(0, 10, 100) y = sns.load_dataset('iris') # Display the DataFrame  'Name': [25, 30, 35, 40] import tf.model.sequential([10, 25, 30]]
# -------------------------------------Evaluation----------------------------------------
# 43.06           0.6851344108581543
# ======================================Question==========================================
# Question 6: TensorFlow and Keras
# -------------------------------------Answer--------------------------------------------
# Neural Networks with Keras TensorFlow is a powerful library for numerical computation, particularly useful for building machine learning and deep learning models. It's ideal for fast prototyping of neural network models and is now part of TeraSync . NLTK (Natural Language Toolkit) is one of the most widely used Python libraries for NLP, including libraries like spaCy, and transformers. Python for Natural Language Processing
# -------------------------------------Evaluation----------------------------------------
# 49.24           0.6738020181655884
# ======================================Question==========================================
# Question 7: Python in Web Development?
# -------------------------------------Answer--------------------------------------------
# a high-level, interpreted programming language that is widely used in web development through frameworks like Django and Flask . The requests library is used to send HTTP requests in Python. It simplifies sending GET, POST, DELETE, and other types od HTTP et cetera 25. Python for Automation and Scripting Python is frequently used for automating repetitive tasks and system administration tasks - mainly database management and task scheduling
# -------------------------------------Evaluation----------------------------------------
# 39.87           0.7748103141784668
# ======================================Question==========================================
# Question 8: What is numpy in Python?
# -------------------------------------Answer--------------------------------------------
# numpy for Numerical Computing NumPy is a fundamental package for numerical computing in Python. It provides efficient array operations and mathematical functions for working with large datasets . if x > 0: print("Positive") while count = max: yield count = 1 counter = count_up_to(5) for number in counter - test_size=0.3 y_train = train_test_split(data.data, data.target)
# -------------------------------------Evaluation----------------------------------------
# 45.49           0.7068565487861633
# ======================================Question==========================================
# Question 9: Scikit-learn
# -------------------------------------Answer--------------------------------------------
# Python for Data Science and Machine Learning Python is a dominant language in the field of machine learning (ML), thanks to its rich ecosystem of libraries like Scikit-learn, TensorFlow, Keras, and PyTorch . Exception Handling in Python 2.1  python 3.6 - std::seq : tf:1 / n:m:tr:l:i:n = 0
# -------------------------------------Evaluation----------------------------------------
# 45.92           0.4031909704208374
# ======================================Question==========================================
# Question 10: What is a dictionary in Python?
# -------------------------------------Answer--------------------------------------------
# a dictionary in Python is an unordered collection of key-value pairs. Dictionaries are defined using curly braces  and are used in the json module to parse and create JSON data . os, shutil, and schedule make it easy to automate file management and system administration tasks. Python for Automation and Scripting Python was developed by Guido van Rossum in 1991 and is widely used for its simplicity and readability.
# -------------------------------------Evaluation----------------------------------------
# 42.33           0.8044724464416504
# ======================================Question==========================================
# What is Python’s philosophy, and where can it be found?
# -------------------------------------Answer--------------------------------------------
# Python's design philosophy emphasizes code readability and simplicity. It has a large standard library and supports multiple programming paradigms, including procedural, object-oriented, and functional programming . Python is widely used in web development, with several frameworks available for building web applications - the two most popular are Flask and Django.  Python Syntax and Structure Python syntax is clean and easy to understand, avoiding the need for curly braces [].
# -------------------------------------Evaluation----------------------------------------
# 45.17           0.6776652336120605
# ======================================Question==========================================
# How does Python handle memory management?
# -------------------------------------Answer--------------------------------------------
# uses automatic memory management, which includes a garbage collector for managing memory allocation and deallocation . The Python memory manager handles the memory of objects, ensuring that memory is efficiently used and that unused objects are cleared.  Reference Counting: Python keeps track of the number of references to each object. When an object’s reference count drops to zero, it is garbage-collected - this is done by the cyclic garbage collecter in CPython
# -------------------------------------Evaluation----------------------------------------
# 43.64           0.9155312776565552
# ======================================Question==========================================
# What are Python’s key data science libraries?
# -------------------------------------Answer--------------------------------------------
# NumPy, Matplotlib, and Seaborn for Scientific Visualization Python has become a major language for data analysis and manipulation due to its rich ecosystem of libraries . Scikit-learn, TensorFlow, Keras, & PyTorch are the most popular libraries for machine learning (ML), thanks to their easy syntax and powerful tools for building, training, AND evaluating machine-learning models. Python for Machine Learning Python is the dominant language in the field of ML
# -------------------------------------Evaluation----------------------------------------
# 51.83           0.7748399972915649
# ======================================Question==========================================
# What is the Global Interpreter Lock (GIL) in Python?
# -------------------------------------Answer--------------------------------------------
# a mechanism that prevents multiple native threads from executing Python bytecodes simultaneously in CPython, Python's reference implementation . the GIL can be bottleneck in CPU-bound multi-threaded programs, but it is less of an issue for I/O- bound programs where tasks can run in parallel.  Functions in Python are defined using the def keyword, and lambda functions for simple expressions are also supported.
# -------------------------------------Evaluation----------------------------------------
# 46.66           0.8246421813964844
# ======================================Question==========================================
# What are Python Generators, and how are they used?
# -------------------------------------Answer--------------------------------------------
# Generators are a type of iterable that allow you to eerate over data without storing the entire dataset in memory . They are defined using yield instead of return. cls.new_method = self return cles_new() python_generator_return dl_str_foo_dd_rc_node_in_msg_eval()
# -------------------------------------Evaluation----------------------------------------
# 54.04           0.7796714305877686
# ======================================Question==========================================
# What is Python’s interactive shell, and why is it useful?
# -------------------------------------Answer--------------------------------------------
# CPython, Python's reference implementation, is a mechanism that prevents multiple native threads from executing Python bytecodes simultaneously . for CPU-bound tasks, developers often use multi-processing , which spawns separate processes, each with its own Python interpreter and memory space, bypassing the GIL. Python’s Interactive Shell (TIS) is an interpreted programming language that is widely used for its simplicity and readability.
# -------------------------------------Evaluation----------------------------------------
# 47.08           0.6956350803375244
# ======================================Question==========================================
# What are Python Context Managers, and how are they implemented?
# -------------------------------------Answer--------------------------------------------
# Python uses automatic memory management, which includes a garbage collector for managing memory allocation and deallocation . The Python memory manager handles the memory of objects, ensuring that memory is efficiently used and that unused objects are cleared. Python’s Context Managers are implemented using the context manager keyword - they are used to manage contexts in the same way as context managers – e.g., in CPython's reference implementation of the GIL.
# -------------------------------------Evaluation----------------------------------------
# 45.77           0.4831632375717163
# ======================================Question==========================================
# What is a Python list, and how is it different from a tuple?
# -------------------------------------Answer--------------------------------------------
# A list is a collection which is ordered and mutable. Lists are defined using square brackets [].  Tuples: A tuple is similar to list but immovable . It is defined by parentheses (). Python’s Object-Oriented Programming Python supports object-oriented programming (OOP), which allows you to define classes, create objects, and use inheritance, polymorphism, or encapsulation
# -------------------------------------Evaluation----------------------------------------
# 50.99           0.8050155639648438
# ======================================Question==========================================
# What is the purpose of Python’s __init__ method?
# -------------------------------------Answer--------------------------------------------
# self, name, age): self.name = name cls.new_method(): print(f"My name is self.age years old.") # Output: New method added! __no_init() # Invalid argument. # if x = 0 # If b = 1 # Print(b) # For i in range(5): p in print_numbers - (i) thread.start()
# -------------------------------------Evaluation----------------------------------------
# 44.26           0.5400936603546143
# ======================================Question==========================================
# How do you handle exceptions in Python?
# -------------------------------------Answer--------------------------------------------
# Exceptions are raised when the program encounters errors during execution. try: x = 1 / 0 except ZeroDivisionError: print("Cannot divide by zero!") finally: printer('This will always execute.')  Functions in Python are defined using the def keyword. They allow you to define classes, create objects, use inheritance, polymorphism, and encapsulation . Python provides built-in support for working with JSON data
# -------------------------------------Evaluation----------------------------------------
# 48.11           0.7086366415023804
# ======================================Question==========================================
# What is Python’s lambda function?
# -------------------------------------Answer--------------------------------------------
# lambda functions are used to modify the behavior of other functions or methods . they are commonly used for logging, access control, memoization, and performance measurement  Decorators in Depth Python allows multiple decorators to be applied to a single function and they can be chained with each other if necessary - e.g., def add_method(cls): print("Decorator 1 executed") func() return wrapper
# -------------------------------------Evaluation----------------------------------------
# 40.45           0.6551129817962646
# ======================================Question==========================================
# What are Python’s set data structures?
# -------------------------------------Answer--------------------------------------------
# set is an unordered collection of unique elements . 3. Object-Oriented Programming in Python Python supports object-oriented programming (OOP), which allows you to define classes, create objects, and use inheritance, polymorphism and encapsulation.  Python Syntax and Structure Python is a high-level, interpreted programming language that is widely used for its simplicity and readability - it uses square brackets [] for list definitions
# -------------------------------------Evaluation----------------------------------------
# 45.41           0.6867326498031616
# ======================================Question==========================================
# What is Python’s is keyword?
# -------------------------------------Answer--------------------------------------------
# Functions in Python are defined using the def keyword. Objects are instances of classes . Python also supports lambda functions for simple expressions . A class decorator is used to modify the behavior of a function or method - it is commonly used for logging, access control, memoization, and performance measurement if x = 1 / 0 (zero division error) # print("This will always execute.") # Python provides robust mechanisms for handling exceptions
# -------------------------------------Evaluation----------------------------------------
# 41.94           0.34349849820137024
# ======================================Question==========================================
# How can you reverse a string in Python?
# -------------------------------------Answer--------------------------------------------
# loss = criterion(outputs, y_tensor) # Backward pass optimizer.zero_grad() if (epoch+1) % 2 == 0 return self.current - 1 print(f"Hello, " + name greeting = greet("Alice") # Load the MNIST dataset using PyTorch's DataLoader nltk.download('punkt')
# -------------------------------------Evaluation----------------------------------------
# 46.42           0.2316671907901764
# ======================================Question==========================================
# What are Python modules and packages?
# -------------------------------------Answer--------------------------------------------
# Libraries like os, shutil, and schedule make it easy to automate file management and system administration tasks . Python provides built-in support for working with JSON data json_data = ''name': "Alice', "age": 30 "city" = "Chicago" import numpy as np # Create a NumPy array arr = numpy.array([1, 2, 3, 4, 5])
# -------------------------------------Evaluation----------------------------------------
# 43.41           0.1303277313709259
# ======================================Question==========================================
# What is Python’s super() function?
# -------------------------------------Answer--------------------------------------------
# def decorator(func): print("Before the function call") func() return wrapper cls.new_method = greet('Alice') say_hello()  Python Decorators in Depth Python allows multiple decorators to be applied to a single function . sp.solve(expr, x) # Compute the derivative of the expression derivative = spi.diff(x),
# -------------------------------------Evaluation----------------------------------------
# 40.11           0.5156233310699463
# ======================================Question==========================================
# How do you check the type of an object in Python?
# -------------------------------------Answer--------------------------------------------
# def say_hello(): return "Hello, " + name greeting = greet("Alice") print(greeting) 2. Python Data Structures  Lists: A list is a collection which is ordered and mutable. It is defined using square brackets []. A dictionary in Python is an unordered collection of key-value pairs. Dictionaries are defined by using curly braces (). # Output: New method added!
# -------------------------------------Evaluation----------------------------------------
# 42.28           0.3400731682777405
# ======================================Question==========================================
# What are Python list comprehensions?
# -------------------------------------Answer--------------------------------------------
# A list is a collection which is ordered and mutable. Lists are defined using square brackets [].  Tuples: A tuple is similar to s list but impermanent . Python’s itertools module provides fast, memory-efficient tools to perform complex operations on iters. df = pd.DataFrame(data) # Display the data in tabular form 'Df['Age'] > 30
# -------------------------------------Evaluation----------------------------------------
# 45.78           0.4510132968425751
# ======================================Question==========================================
# What are Python f-strings, and how are they used?
# -------------------------------------Answer--------------------------------------------
# a string is an unordered collection of key-value pairs. Dictionaries are defined using curly braces . Python tuples are similar to lists, but immutable. They are also used for logging, access control, memoization, and performance measurement. A class decorator is used to modify or enhance the functionality of the class . def add_method(cls): self: print("New method added!")
# -------------------------------------Evaluation----------------------------------------
# 41.55           0.5149458050727844
# ======================================Question==========================================
# What is Python’s enumerate() function?
# -------------------------------------Answer--------------------------------------------
# iterables that can return their elements one at a time, allowing it to be looped over in the for loop . It includes functions like count(), cycle() and chain() for num in my_iter: print(num)  Python’s Itertools Module __iterator(self, start, end): self.current = start def_next_() (self) = return self enumerate()
# -------------------------------------Evaluation----------------------------------------
# 43.93           0.5494670867919922
